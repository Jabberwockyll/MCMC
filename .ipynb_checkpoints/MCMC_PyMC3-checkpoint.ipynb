# %% [markdown]
# # 1a. Hierarchical Pooling Model

# %%
from pymc3 import Model, Normal, Uniform, Gamma, Deterministic
from pymc3.math import sqrt
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
% matplotlib inline

school_obs = np.array([28, 8, -3, 7,-1, 1, 18, 12])
sigmas = np.array([15, 10, 16, 11, 9, 11, 10, 18])

hierarch_model = Model()

with hierarch_model:
    
    mu = Normal('mu', 0, np.power(10, 6))
    itau = Gamma('itau', 1e-3, np.power(15, 2)*1e-3)
    tau = Deterministic("tau", 1 / sqrt(itau))
    
    theta = []
    y = []
    
    for j in range(len(school_obs)):
        theta.append(Normal('theta{0}'.format(j+1), mu=mu, sd=tau))
        y.append(Normal('y{0}'.format(j+1), mu=theta[j], sd=sigmas[j], observed=school_obs[j]))

# %%
from pymc3 import NUTS, sample
from scipy import optimize

with hierarch_model:
    hierarch_trace=sample(10000, njobs=3)

# %%
from pymc3 import traceplot, summary

traceplot(hierarch_trace)
summary(hierarch_trace)
# Out:
# mu:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   7.938            4.796            0.077            [-1.071, 17.693]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -1.385         4.778          7.891          11.044         17.433
#
#
# theta1:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   10.205           7.190            0.116            [-3.370, 24.936]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -1.812         5.544          9.465          13.836         27.199
#
#
# theta2:
#
# ...

# %%
import pymc3 as pm

hierarch_dic = pm.stats.dic(model=hierarch_model, trace=hierarch_trace)
print("DIC for hierarchical pooling model: {0}".format(hierarch_dic))
# Out:
# DIC for hierarchical pooling model: 155.21828157697

# %% [markdown]
# # 1b No-Pooling Model

# %%
no_pool_model = Model()

with no_pool_model:
    theta = []
    y = []
    
    for j in range(len(school_obs)):
        theta.append(Uniform('theta{0}'.format(j+1), -1000, 1000))
        y.append(Normal('y{0}'.format(j+1), mu=theta[j], sd=sigmas[j], observed=school_obs[j]))

# %%
with no_pool_model:
    no_pool_trace=sample(10000, njobs=3)

# %%
traceplot(no_pool_trace)
summary(no_pool_trace)
# Out:
# theta1:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   28.186           14.842           0.074            [-0.745, 57.243]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.578         18.104         28.151         38.150         57.460
#
#
# theta2:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   7.960            10.062           0.041            [-11.962, 27.234]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -11.703        1.105          8.037          14.764         27.579
#
#
# theta3:
#
# ...

# %%
no_pool_dic = pm.stats.dic(model=no_pool_model, trace=no_pool_trace)
print("DIC for no pooling model: {0}".format(no_pool_dic))
# Out:
# DIC for no pooling model: 92.70582526012595

# %% [markdown]
# # 1c Complete Pooling Model

# %%
complete_pool_model = Model()

with complete_pool_model:
    theta = Uniform('theta', -1000, 1000)
    y = []
    
    for j in range(len(school_obs)):
        y.append(Normal('y{0}'.format(j+1), mu=theta, sd=sigmas[j], observed=school_obs[j]))

# %%
with complete_pool_model:
    complete_pool_trace=sample(10000, njobs=3)

# %%
traceplot(complete_pool_trace)
summary(complete_pool_trace)
# Out:
# theta:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   7.596            3.990            0.036            [-0.554, 15.310]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   -0.374         4.994          7.587          10.236         15.509

# %%
complete_pool_dic = pm.stats.dic(model=complete_pool_model, trace=complete_pool_trace)
print("DIC for complete pooling model: {0}".format(complete_pool_dic))
# Out:
# DIC for complete pooling model: 64.09122366979878

# %% [markdown]
# # 1d DIC Comparison

# %%
print("Model                |  DIC")
print("----------------------------------------")
print("Hierarchical Pooling | {0}".format(hierarch_dic))
print("No Pooling           | {0}".format(no_pool_dic))
print("Complete Pooling     | {0}".format(complete_pool_dic))
# Out:
# Model                |  DIC
# ----------------------------------------
# Hierarchical Pooling | 155.21828157697
# No Pooling           | 92.70582526012595
# Complete Pooling     | 64.09122366979878

# %% [markdown]
# Based on DIC score comparisons, the complete pooling model looks much more favorable than the other two.  I was surprised that the difference is so large, given the examples we saw in class.  The posteriors from the complete pooling model and hierarchical model look similar.  The posteriors for the thetas from the no pooling models have very different means and large variances, but that makes sense given that they are completely independent in our prior.

# %% [markdown]
# # 2aNuclear Pumps Model

# %%
from pymc3 import Poisson

t = np.array([94.5, 15.7, 62.9, 126.0, 5.2, 31.4, 1.05, 1.05, 2.1, 10.5]) # Length of operation per pump
failures = np.array([5, 1, 5, 14, 3, 19, 1, 1, 4, 22]) # number of failures per pump

pump_model = Model()
with pump_model:
    beta = Gamma('beta', 1, 1)
    theta = []
    y = []
    
    for i in range(len(failures)):
        theta.append(Gamma('theta{0}'.format(i+1), 1, beta))
        y.append(Poisson('y{0}'.format(i+1), theta[i]*t[i], observed=(failures[i])))

# %%
with pump_model:
    pump_trace=sample(10000, njobs=3)

# %% [markdown]
# # 2b Pump model diagnostics

# %%
traceplot(pump_trace)
summary(pump_trace)
pm.plots.autocorrplot(pump_trace, varnames=["theta1"])
# Out:
# beta:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   1.496            0.530            0.003            [0.554, 2.534]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.670          1.115          1.422          1.800          2.736
#
#
# theta1:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.063            0.025            0.000            [0.018, 0.113]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.023          0.044          0.059          0.077          0.121
#
#
# theta2:
#
# ...

# %%
print("Gelman-Rubin statistic: {0}".format(pm.diagnostics.gelman_rubin(pump_trace)["theta1"]))
# Out:
# Gelman-Rubin statistic: 1.0000332518272594

# %% [markdown]
# The sample paths show that MCMC is exploring the parameter space sufficiently and not getting stuck on values.  The acf plots show virtually no autocorrelation over different lags, so our Markov chains are actually showing the Markov property.  And the Gelman-Rubin statistic is approximately equal to one, so our chains are robust to the starting value.  All of these indicate that our MCMC is working very well.

# %% [markdown]
# # 2c Pump Model 2

# %%
from pymc3 import Exponential

pump_model2 = Model()
with pump_model2:
    beta = Gamma('beta', 1, 1)
    alpha = Exponential('alpha', 1)
    theta = []
    y = []
    
    for i in range(len(failures)):
        theta.append(Gamma('theta{0}'.format(i+1), alpha, beta))
        y.append(Poisson('y{0}'.format(i+1), theta[i]*t[i], observed=(failures[i])))

# %%
with pump_model2:
    pump_trace2=sample(10000, njobs=3)

# %%
summary(pump_trace2)
# Out:
# beta:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   1.211            0.621            0.005            [0.245, 2.480]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.323          0.761          1.104          1.537          2.715
#
#
# alpha:
#
#   Mean             SD               MC Error         95% HPD interval
#   -------------------------------------------------------------------
#
#   0.795            0.294            0.002            [0.282, 1.372]
#
#   Posterior quantiles:
#   2.5            25             50             75             97.5
#   |--------------|==============|==============|--------------|
#
#   0.343          0.584          0.752          0.961          1.484
#
#
# theta1:
#
# ...

# %% [markdown]
# # 2d DIC Comparison

# %%
print("Model                     |  DIC")
print("--------------------------------------------")
print("Model without alpha prior | {0}".format(
    pm.stats.dic(model=pump_model, trace=pump_trace)))
print("Model with alpha prior    | {0}".format(
    pm.stats.dic(model=pump_model2, trace=pump_trace2)))
# Out:
# Model                     |  DIC
# --------------------------------------------
# Model without alpha prior | 90.05024860221326
# Model with alpha prior    | 94.54613380674941

# %% [markdown]
# There isn't a strong (>5) difference in the DIC between the two models, but I would still choose the model without the prior on alpha, since it has a lower DIC.
